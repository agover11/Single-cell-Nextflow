# %% [markdown]
# # Load scanpy, anndata, and matplotlib.pyplot

# %%
# !pip install scikit-image
import scanpy as sc
import anndata as ad
import celltypist
from celltypist import models
import skimage
# Out:
# Requirement already satisfied: scikit-image in /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages (from scikit-image) (2.3.5)
# Requirement already satisfied: scipy>=1.11.4 in /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages (from scikit-image) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages (from scikit-image) (12.0.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages (from scikit-image) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages (from scikit-image) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages (from scikit-image) (0.4)

# %% [markdown]
# # Read in samples separately (Find an appropriate function to read in 10x data from a matrix)

# %%
sample1 = sc.read_10x_mtx('/projectnb/bf528/materials/single_cell/hipp_rep1/outs/filtered_feature_bc_matrix/')
sample2 = sc.read_10x_mtx('/projectnb/bf528/materials/single_cell/hipp_rep2/outs/filtered_feature_bc_matrix/')

# %% [markdown]
# # How many genes and cells are present in each sample? (Use the .var and .obs dataframes)

# %%
sample1.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACCTGAGATGCCAG-1, AAACCTGAGGCGCTCT-1, AAACCTGCAACACCTA-1, AAACCTGCATGCCTAA-1, AAACCTGGTCGAACAG-1, AAACCTGGTGCGCTTG-1, AAACCTGGTGGTACAG-1, AAACCTGGTTAAGACA-1, AAACCTGGTTATTCTC-1, AAACCTGGTTTGTTGG-1, AAACCTGTCCTTTACA-1, AAACCTGTCGGCATCG-1, AAACCTGTCTGGCGTG-1, AAACCTGTCTTGGGTA-1, AAACGGGAGCGATCCC-1, AAACGGGAGCTGCCCA-1, AAACGGGAGCTGTCTA-1, AAACGGGAGGTTCCTA-1, AAACGGGAGTACGCCC-1, AAACGGGAGTATCTCG-1, AAACGGGAGTGGAGAA-1, AAACGGGCAATGAATG-1, AAACGGGCACCACGTG-1, AAACGGGCAGTTCATG-1, AAACGGGCATGGTAGG-1, AAACGGGGTACAGTTC-1, AAACGGGGTCACCCAG-1, AAACGGGGTGCATCTA-1, AAACGGGTCCACGACG-1, AAACGGGTCCCAAGTA-1, AAACGGGTCCCTGACT-1, AAACGGGTCGATGAGG-1, AAACGGGTCTCGATGA-1, AAACGGGTCTGCTGTC-1, AAAGATGAGACAGACC-1, AAAGATGAGACTAGAT-1, AAAGATGAGATCTGCT-1, AAAGATGAGATGGCGT-1, AAAGATGAGCCACGTC-1, AAAGATGAGCCGCCTA-1, AAAGATGAGCGTAATA-1, AAAGATGAGCTCCTCT-1, AAAGATGAGGCAAAGA-1, AAAGATGAGTATCGAA-1, AAAGATGAGTGTTAGA-1, AAAGATGCAATGGAAT-1, AAAGATGCACACTGCG-1, AAAGATGCACTAGTAC-1, AAAGATGCATCGGGTC-1, AAAGATGGTAGGACAC-1, AAAGATGGTCTGCCAG-1, AAAGATGGTGCACTTA-1, AAAGATGGTTCAGCGC-1, AAAGATGGTTGGTAAA-1, AAAGATGTCACCGGGT-1, AAAGATGTCATCGATG-1, AAAGATGTCGAATGCT-1, AAAGATGTCGCCTGAG-1, AAAGATGTCTCTGTCG-1, AAAGCAAAGATGGGTC-1, AAAGCAAAGCACACAG-1, AAAGCAAAGGGATCTG-1, AAAGCAAAGGTGATAT-1, AAAGCAAAGGTGTGGT-1, AAAGCAAAGTTTGCGT-1, AAAGCAACAAAGAATC-1, AAAGCAACACATAACC-1, AAAGCAACACTGCCAG-1, AAAGCAACAGTATCTG-1, AAAGCAACATGAGCGA-1, AAAGCAACATGCTAGT-1, AAAGCAACATTGGGCC-1, AAAGCAAGTATCGCAT-1, AAAGCAAGTCCAACTA-1, AAAGCAAGTCTCAACA-1, AAAGCAAGTGTAATGA-1, AAAGCAAGTTCAGGCC-1, AAAGCAAGTTCGCGAC-1, AAAGCAATCACCGGGT-1, AAAGCAATCACGGTTA-1, AAAGCAATCACTCTTA-1, AAAGCAATCGCCGTGA-1, AAAGCAATCTCATTCA-1, AAAGCAATCTGTCTCG-1, AAAGTAGAGCCACGCT-1, AAAGTAGAGCGTGTCC-1, AAAGTAGAGCTGCAAG-1, AAAGTAGAGGATGCGT-1, AAAGTAGAGGTTACCT-1, AAAGTAGCAACACCCG-1, AAAGTAGCAAGCCATT-1, AAAGTAGCACCCATTC-1, AAAGTAGCACGTAAGG-1, AAAGTAGCAGCCAATT-1, AAAGTAGCATCTATGG-1, AAAGTAGGTCGCTTCT-1, AAAGTAGGTGATAAAC-1, AAAGTAGTCGTGGTCG-1, AAAGTAGTCTCCGGTT-1, AAATGCCAGACCTTTG-1, ...]
#
# [8617 rows x 0 columns]

# %%
sample2
# Out:
# AnnData object with n_obs × n_vars = 9283 × 33696
#     var: 'gene_ids', 'feature_types'

# %% [markdown]
# # Identify which genes correspond to mitochondrial, ribosomal and hemoglobin genes per barcode

# %%
sample1.var["mt"] = sample1.var_names.str.startswith("mt-")
sample1.var["ribo"] = sample1.var_names.str.startswith(("Rps", "Rpl"))
sample1.var["hb"] = sample1.var_names.str.contains("^Hb[^(P)]")

sample2.var["mt"] = sample2.var_names.str.startswith("mt-")
sample2.var["ribo"] = sample2.var_names.str.startswith(("Rps", "Rpl"))
sample2.var["hb"] = sample2.var_names.str.contains("^Hb[^(P)]")

# %%
sample1.var
# Out:
#                               gene_ids    feature_types     mt   ribo     hb
# Xkr4                ENSMUSG00000051951  Gene Expression  False  False  False
# Gm1992              ENSMUSG00000089699  Gene Expression  False  False  False
# Gm19938             ENSMUSG00000102331  Gene Expression  False  False  False
# Gm37381             ENSMUSG00000102343  Gene Expression  False  False  False
# Rp1                 ENSMUSG00000025900  Gene Expression  False  False  False
# ...                                ...              ...    ...    ...    ...
# ENSMUSG00000095523  ENSMUSG00000095523  Gene Expression  False  False  False
# ENSMUSG00000095475  ENSMUSG00000095475  Gene Expression  False  False  False
# ENSMUSG00000094855  ENSMUSG00000094855  Gene Expression  False  False  False
# ENSMUSG00000095019  ENSMUSG00000095019  Gene Expression  False  False  False
# ENSMUSG00000095041  ENSMUSG00000095041  Gene Expression  False  False  False
#
# [33696 rows x 5 columns]

# %% [markdown]
# # Actually calculate QC metrics per barcode / cell

# %%
sc.pp.calculate_qc_metrics(
    sample1, qc_vars=["mt", "ribo", "hb"], inplace=True, log1p=True
)

sc.pp.calculate_qc_metrics(
    sample2, qc_vars=["mt", "ribo", "hb"], inplace=True, log1p=True
)

# %% [markdown]
# # Access the .obs and return a dataframe only containing cells with less than 1000 genes

# %% [markdown]
# ### This is just practice subsetting anndata objects with pandas-like operations

# %%
sample1.obs
# Out:
#                     n_genes_by_counts  log1p_n_genes_by_counts  total_counts  \
# AAACCTGAGATGCCAG-1               2409                 7.787382        4126.0
# AAACCTGAGGCGCTCT-1               2273                 7.729296        5077.0
# AAACCTGCAACACCTA-1               1929                 7.565275        3646.0
# AAACCTGCATGCCTAA-1               3830                 8.250881       10013.0
# AAACCTGGTCGAACAG-1               1125                 7.026427        1750.0
# ...                               ...                      ...           ...
# TTTGTCAGTTGCGCAC-1               1790                 7.490529        3283.0
# TTTGTCATCAATCTCT-1                348                 5.855072         533.0
# TTTGTCATCACTGGGC-1               1074                 6.980076        1983.0
# TTTGTCATCGATCCCT-1               2479                 7.816014        5206.0
# TTTGTCATCTTAGAGC-1               1299                 7.170120        2030.0
#
#                     log1p_total_counts  pct_counts_in_top_50_genes  \
# AAACCTGAGATGCCAG-1            8.325306                   19.946680
# AAACCTGAGGCGCTCT-1            8.532673                   23.616309
# AAACCTGCAACACCTA-1            8.201660                   25.150850
# AAACCTGCATGCCTAA-1            9.211740                   17.367422
# AAACCTGGTCGAACAG-1            7.467942                   26.457143
# ...                                ...                         ...
# TTTGTCAGTTGCGCAC-1            8.096817                   24.703016
# TTTGTCATCAATCTCT-1            6.280396                   43.527205
# TTTGTCATCACTGGGC-1            7.592870                   27.937468
# TTTGTCATCGATCCCT-1            8.557759                   20.303496
# TTTGTCATCTTAGAGC-1            7.616283                   21.133005
#
#                     pct_counts_in_top_100_genes  pct_counts_in_top_200_genes  \
# AAACCTGAGATGCCAG-1                    25.666505                    33.858459
# AAACCTGAGGCGCTCT-1                    32.263148                    43.116013
# AAACCTGCAACACCTA-1                    32.364235                    41.689523
# AAACCTGCATGCCTAA-1                    25.137321                    35.513832
# AAACCTGGTCGAACAG-1                    34.457143                    45.885714
# ...                                         ...                          ...
# TTTGTCAGTTGCGCAC-1                    33.170880                    43.253122
# TTTGTCATCAATCTCT-1                    53.470919                    72.232645
# TTTGTCATCACTGGGC-1                    38.275340                    50.882501
# TTTGTCATCGATCCCT-1                    28.275067                    38.820592
# TTTGTCATCTTAGAGC-1                    29.802956                    41.083744
#
#                     pct_counts_in_top_500_genes  total_counts_mt  \
# AAACCTGAGATGCCAG-1                    50.096946            346.0
# AAACCTGAGGCGCTCT-1                    59.661217            320.0
# AAACCTGCAACACCTA-1                    59.544707            214.0
# AAACCTGCATGCCTAA-1                    51.612903            369.0
# AAACCTGGTCGAACAG-1                    64.285714            118.0
# ...                                         ...              ...
# TTTGTCAGTTGCGCAC-1                    60.706671            159.0
# TTTGTCATCAATCTCT-1                   100.000000            110.0
# TTTGTCATCACTGGGC-1                    71.053959            199.0
# TTTGTCATCGATCCCT-1                    55.781790            283.0
# TTTGTCATCTTAGAGC-1                    60.640394            145.0
#
#                     log1p_total_counts_mt  pct_counts_mt  total_counts_ribo  \
# AAACCTGAGATGCCAG-1               5.849325       8.385846              255.0
# AAACCTGAGGCGCTCT-1               5.771441       6.302935              660.0
# AAACCTGCAACACCTA-1               5.370638       5.869446              293.0
# AAACCTGCATGCCTAA-1               5.913503       3.685209              957.0
# AAACCTGGTCGAACAG-1               4.779123       6.742857              105.0
# ...                                   ...            ...                ...
# TTTGTCAGTTGCGCAC-1               5.075174       4.843132              497.0
# TTTGTCATCAATCTCT-1               4.709530      20.637897               35.0
# TTTGTCATCACTGGGC-1               5.298317      10.035300              245.0
# TTTGTCATCGATCCCT-1               5.648974       5.436035              507.0
# TTTGTCATCTTAGAGC-1               4.983607       7.142858              234.0
#
#                     log1p_total_counts_ribo  pct_counts_ribo  total_counts_hb  \
# AAACCTGAGATGCCAG-1                 5.545177         6.180320              0.0
# AAACCTGAGGCGCTCT-1                 6.493754        12.999803              1.0
# AAACCTGCAACACCTA-1                 5.683580         8.036204              2.0
# AAACCTGCATGCCTAA-1                 6.864848         9.557575              0.0
# AAACCTGGTCGAACAG-1                 4.663439         6.000000              0.0
# ...                                     ...              ...              ...
# TTTGTCAGTTGCGCAC-1                 6.210600        15.138594              0.0
# TTTGTCATCAATCTCT-1                 3.583519         6.566604              0.0
# TTTGTCATCACTGGGC-1                 5.505332        12.355018              1.0
# TTTGTCATCGATCCCT-1                 6.230482         9.738763              0.0
# TTTGTCATCTTAGAGC-1                 5.459586        11.527094              0.0
#
#                     log1p_total_counts_hb  pct_counts_hb
# AAACCTGAGATGCCAG-1               0.000000       0.000000
# AAACCTGAGGCGCTCT-1               0.693147       0.019697
# AAACCTGCAACACCTA-1               1.098612       0.054855
# AAACCTGCATGCCTAA-1               0.000000       0.000000
# AAACCTGGTCGAACAG-1               0.000000       0.000000
# ...                                   ...            ...
# TTTGTCAGTTGCGCAC-1               0.000000       0.000000
# TTTGTCATCAATCTCT-1               0.000000       0.000000
# TTTGTCATCACTGGGC-1               0.693147       0.050429
# TTTGTCATCGATCCCT-1               0.000000       0.000000
# TTTGTCATCTTAGAGC-1               0.000000       0.000000
#
# [8617 rows x 17 columns]

# %% [markdown]
# # How many cells / barcodes have less than 1000 genes in each sample?

# %%
sample1.obs[sample1.obs['n_genes_by_counts'] < 1000]
# Out:
#                     n_genes_by_counts  log1p_n_genes_by_counts  total_counts  \
# AAACCTGGTGCGCTTG-1                489                 6.194405         761.0
# AAACCTGGTTAAGACA-1                859                 6.756932        1461.0
# AAACCTGTCTTGGGTA-1                459                 6.131226         594.0
# AAACGGGAGCTGTCTA-1                719                 6.579251        1092.0
# AAACGGGAGTATCTCG-1                876                 6.776507        1439.0
# ...                               ...                      ...           ...
# TTTGCGCCAATTCCTT-1                964                 6.872128        1564.0
# TTTGCGCGTATTCGTG-1                610                 6.415097         940.0
# TTTGTCAAGGTGCAAC-1                391                 5.971262         528.0
# TTTGTCAAGTGGTAAT-1                519                 6.253829         768.0
# TTTGTCATCAATCTCT-1                348                 5.855072         533.0
#
#                     log1p_total_counts  pct_counts_in_top_50_genes  \
# AAACCTGGTGCGCTTG-1            6.635947                   37.319317
# AAACCTGGTTAAGACA-1            7.287560                   29.500342
# AAACCTGTCTTGGGTA-1            6.388561                   30.303030
# AAACGGGAGCTGTCTA-1            6.996682                   27.380952
# AAACGGGAGTATCTCG-1            7.272398                   32.939541
# ...                                ...                         ...
# TTTGCGCCAATTCCTT-1            7.355641                   31.841432
# TTTGCGCGTATTCGTG-1            6.846943                   33.297872
# TTTGTCAAGGTGCAAC-1            6.270988                   32.007576
# TTTGTCAAGTGGTAAT-1            6.645091                   30.859375
# TTTGTCATCAATCTCT-1            6.280396                   43.527205
#
#                     pct_counts_in_top_100_genes  pct_counts_in_top_200_genes  \
# AAACCTGGTGCGCTTG-1                    48.883049                    62.023653
# AAACCTGGTTAAGACA-1                    40.109514                    53.935661
# AAACCTGTCTTGGGTA-1                    39.562290                    56.397306
# AAACGGGAGCTGTCTA-1                    37.820513                    52.472527
# AAACGGGAGTATCTCG-1                    40.861710                    53.022933
# ...                                         ...                          ...
# TTTGCGCCAATTCCTT-1                    39.514066                    51.150895
# TTTGCGCGTATTCGTG-1                    43.936170                    56.382979
# TTTGTCAAGGTGCAAC-1                    44.886364                    63.825758
# TTTGTCAAGTGGTAAT-1                    43.880208                    58.463542
# TTTGTCATCAATCTCT-1                    53.470919                    72.232645
#
#                     pct_counts_in_top_500_genes  total_counts_mt  \
# AAACCTGGTGCGCTTG-1                   100.000000             82.0
# AAACCTGGTTAAGACA-1                    75.427789            111.0
# AAACCTGTCTTGGGTA-1                   100.000000             35.0
# AAACGGGAGCTGTCTA-1                    79.945055             77.0
# AAACGGGAGTATCTCG-1                    73.870744            156.0
# ...                                         ...              ...
# TTTGCGCCAATTCCTT-1                    70.332481            236.0
# TTTGCGCGTATTCGTG-1                    88.297872            133.0
# TTTGTCAAGGTGCAAC-1                   100.000000             45.0
# TTTGTCAAGTGGTAAT-1                    97.526042             69.0
# TTTGTCATCAATCTCT-1                   100.000000            110.0
#
#                     log1p_total_counts_mt  pct_counts_mt  total_counts_ribo  \
# AAACCTGGTGCGCTTG-1               4.418840      10.775295               42.0
# AAACCTGGTTAAGACA-1               4.718499       7.597536              186.0
# AAACCTGTCTTGGGTA-1               3.583519       5.892256               20.0
# AAACGGGAGCTGTCTA-1               4.356709       7.051282              202.0
# AAACGGGAGTATCTCG-1               5.056246      10.840861               45.0
# ...                                   ...            ...                ...
# TTTGCGCCAATTCCTT-1               5.468060      15.089514               34.0
# TTTGCGCGTATTCGTG-1               4.897840      14.148935               95.0
# TTTGTCAAGGTGCAAC-1               3.828641       8.522727              102.0
# TTTGTCAAGTGGTAAT-1               4.248495       8.984375              102.0
# TTTGTCATCAATCTCT-1               4.709530      20.637897               35.0
#
#                     log1p_total_counts_ribo  pct_counts_ribo  total_counts_hb  \
# AAACCTGGTGCGCTTG-1                 3.761200         5.519054              0.0
# AAACCTGGTTAAGACA-1                 5.231109        12.731007              0.0
# AAACCTGTCTTGGGTA-1                 3.044523         3.367003              0.0
# AAACGGGAGCTGTCTA-1                 5.313206        18.498169              0.0
# AAACGGGAGTATCTCG-1                 3.828641         3.127172              0.0
# ...                                     ...              ...              ...
# TTTGCGCCAATTCCTT-1                 3.555348         2.173913              0.0
# TTTGCGCGTATTCGTG-1                 4.564348        10.106383              1.0
# TTTGTCAAGGTGCAAC-1                 4.634729        19.318182              0.0
# TTTGTCAAGTGGTAAT-1                 4.634729        13.281250              0.0
# TTTGTCATCAATCTCT-1                 3.583519         6.566604              0.0
#
#                     log1p_total_counts_hb  pct_counts_hb
# AAACCTGGTGCGCTTG-1               0.000000       0.000000
# AAACCTGGTTAAGACA-1               0.000000       0.000000
# AAACCTGTCTTGGGTA-1               0.000000       0.000000
# AAACGGGAGCTGTCTA-1               0.000000       0.000000
# AAACGGGAGTATCTCG-1               0.000000       0.000000
# ...                                   ...            ...
# TTTGCGCCAATTCCTT-1               0.000000       0.000000
# TTTGCGCGTATTCGTG-1               0.693147       0.106383
# TTTGTCAAGGTGCAAC-1               0.000000       0.000000
# TTTGTCAAGTGGTAAT-1               0.000000       0.000000
# TTTGTCATCAATCTCT-1               0.000000       0.000000
#
# [2001 rows x 17 columns]

# %% [markdown]
# # Plot both sample's QC metrics with violin plots

# %%
sc.pl.violin(
    sample1,
    ["n_genes_by_counts", "total_counts", "pct_counts_mt", "pct_counts_ribo", "pct_counts_hb"],
    jitter=0.4,
    multi_panel=True,
)

sc.pl.violin(
    sample2,
    ["n_genes_by_counts", "total_counts", "pct_counts_mt", "pct_counts_ribo", "pct_counts_hb"],
    jitter=0.4,
    multi_panel=True,
)
# Out:
# ... storing 'feature_types' as categorical
# ... storing 'feature_types' as categorical

# %% [markdown]
# # Plot metrics jointly for each sample

# %%
sc.pl.scatter(sample1, "total_counts", "n_genes_by_counts", color="pct_counts_mt")

# %% [markdown]
# # Filter your datasets based on the above thresholds and use the built-in scrublet method

# %%
sc.pp.filter_cells(sample1, min_genes=100)
sc.pp.filter_genes(sample1, min_cells=3)
sc.pp.scrublet(sample1)

sc.pp.filter_cells(sample2, min_genes=100)
sc.pp.filter_genes(sample2, min_cells=3)
sc.pp.scrublet(sample2)

# %% [markdown]
# # How many genes and cells were present before and after filtering?

# %%
sample2.var
# Out:
#                               gene_ids    feature_types     mt   ribo     hb  \
# Xkr4                ENSMUSG00000051951  Gene Expression  False  False  False
# Gm1992              ENSMUSG00000089699  Gene Expression  False  False  False
# Gm19938             ENSMUSG00000102331  Gene Expression  False  False  False
# Rp1                 ENSMUSG00000025900  Gene Expression  False  False  False
# Sox17               ENSMUSG00000025902  Gene Expression  False  False  False
# ...                                ...              ...    ...    ...    ...
# mt-Nd6              ENSMUSG00000064368  Gene Expression   True  False  False
# mt-Cytb             ENSMUSG00000064370  Gene Expression   True  False  False
# ENSMUSG00000079808  ENSMUSG00000079808  Gene Expression  False  False  False
# ENSMUSG00000095742  ENSMUSG00000095742  Gene Expression  False  False  False
# ENSMUSG00000095041  ENSMUSG00000095041  Gene Expression  False  False  False
#
#                     n_cells_by_counts  mean_counts  log1p_mean_counts  \
# Xkr4                             2130     0.461704           0.379603
# Gm1992                            176     0.019821           0.019627
# Gm19938                           489     0.060110           0.058373
# Rp1                                29     0.003770           0.003763
# Sox17                             158     0.039750           0.038980
# ...                               ...          ...                ...
# mt-Nd6                            321     0.035980           0.035348
# mt-Cytb                          9248    22.598944           3.161202
# ENSMUSG00000079808                  7     0.000754           0.000754
# ENSMUSG00000095742                  9     0.000970           0.000969
# ENSMUSG00000095041               2510     0.391145           0.330127
#
#                     pct_dropout_by_counts  total_counts  log1p_total_counts  \
# Xkr4                            77.054831        4286.0            8.363342
# Gm1992                          98.104061         184.0            5.220356
# Gm19938                         94.732306         558.0            6.326149
# Rp1                             99.687601          35.0            3.583519
# Sox17                           98.297964         369.0            5.913503
# ...                                   ...           ...                 ...
# mt-Nd6                          96.542066         334.0            5.814131
# mt-Cytb                          0.377033      209786.0           12.253848
# ENSMUSG00000079808              99.924593           7.0            2.079442
# ENSMUSG00000095742              99.903049           9.0            2.302585
# ENSMUSG00000095041              72.961327        3631.0            8.197538
#
#                     n_cells
# Xkr4                   2130
# Gm1992                  176
# Gm19938                 489
# Rp1                      29
# Sox17                   158
# ...                     ...
# mt-Nd6                  321
# mt-Cytb                9247
# ENSMUSG00000079808        7
# ENSMUSG00000095742        9
# ENSMUSG00000095041     2510
#
# [21455 rows x 12 columns]

# %% [markdown]
# | # of Cells | Sample 1 | Sample 2 |
# | ---------- | -------- | -------- |
# | Before     |          |          |
# | After      |          |          |

# %% [markdown]
# # Combine both samples together using Anndata concat

# %%
adata = ad.concat([sample1, sample2], join='outer', label="replicate", keys=["rep1", "rep2"])
adata_celltypist = adata.copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 17883 × 22837
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'n_genes', 'doublet_score', 'predicted_doublet', 'replicate'

# %% [markdown]
# # Copy counts, normalize counts, and Log(x+1) transform

# %%
adata.layers["counts"] = adata.X.copy()
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)

# %% [markdown]
# # Determine highly variable genes

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=2000, batch_key="replicate")

# %%
sc.pl.highly_variable_genes(adata)

# %% [markdown]
# # Inspect the highly variable genes

# %%
adata.var
# Out:
#                highly_variable     means  dispersions  dispersions_norm  \
# 0610005C13Rik            False  0.001207     0.002858     -7.768320e-01
# 0610006L08Rik            False  0.000165    -0.079359     -4.241872e-01
# 0610009B22Rik            False  0.155847     0.342345      1.484185e-02
# 0610009E02Rik            False  0.010161     0.408296      2.596137e-01
# 0610009L18Rik            False  0.071232     0.348364      5.034093e-02
# ...                        ...       ...          ...               ...
# mt-Nd3                   False  0.763551     0.955092      1.855362e-01
# mt-Nd4                   False  2.699090     2.133701     -1.110223e-16
# mt-Nd4l                  False  0.312788     0.630224      2.905129e-01
# mt-Nd5                   False  0.630251     0.789056     -1.076497e-01
# mt-Nd6                   False  0.042448     0.641106      7.793810e-01
#
#                highly_variable_nbatches  highly_variable_intersection
# 0610005C13Rik                         0                         False
# 0610006L08Rik                         0                         False
# 0610009B22Rik                         0                         False
# 0610009E02Rik                         0                         False
# 0610009L18Rik                         0                         False
# ...                                 ...                           ...
# mt-Nd3                                0                         False
# mt-Nd4                                0                         False
# mt-Nd4l                               0                         False
# mt-Nd5                                0                         False
# mt-Nd6                                0                         False
#
# [22837 rows x 6 columns]

# %%
sc.tl.pca(adata)

# %% [markdown]
# # Perform PCA and examine PCA - Variance Ratio

# %%
sc.pl.pca_variance_ratio(adata, n_pcs=50, log=True)

# %% [markdown]
# # Compute the nearest neighbors graph

# %%
sc.pp.neighbors(adata)

# %% [markdown]
# # Run UMAP and be sure to set a random_state

# %%
sc.tl.umap(adata, random_state=42)

# %% [markdown]
# # Perform Leiden clustering

# %%
sc.tl.leiden(adata, flavor="igraph", n_iterations=2)
sc.pl.umap(adata, color=["leiden"], legend_loc='on data')

# %% [markdown]
# # Overlay Doublet scores onto UMAP

# %%
sc.pl.umap(
    adata,
    color=["leiden", "predicted_doublet", "doublet_score"],
    # increase horizontal space between panels
    wspace=0.5,
    ncols=1,
    size=3,
)

# %% [markdown]
# # Overlay QC metrics onto UMAP

# %%
sc.pl.umap(
    adata,
    color=["leiden", "log1p_total_counts", "pct_counts_mt", "log1p_n_genes_by_counts", "pct_counts_hb", "pct_counts_ribo"],
    wspace=0.5,
    ncols=2,
)

# %% [markdown]
# # Overlay replicate status onto UMAP

# %%
sc.pl.umap(adata,color=["replicate", "leiden"], alpha=0.5)

# %% [markdown]
# # Experiment with different resolution values for clustering

# %%
sc.tl.leiden(adata, key_added="leiden_res_0.5", resolution=0.5,flavor="igraph")

# %%
adata.obs
# Out:
#                     n_genes_by_counts  log1p_n_genes_by_counts  total_counts  \
# AAACCTGAGATGCCAG-1               2409                 7.787382        4126.0
# AAACCTGAGGCGCTCT-1               2273                 7.729296        5077.0
# AAACCTGCAACACCTA-1               1929                 7.565275        3646.0
# AAACCTGCATGCCTAA-1               3830                 8.250881       10013.0
# AAACCTGGTCGAACAG-1               1125                 7.026427        1750.0
# ...                               ...                      ...           ...
# TTTGTCATCACATACG-1               1304                 7.173958        2179.0
# TTTGTCATCCCTTGCA-1               1160                 7.057037        1906.0
# TTTGTCATCCGTAGTA-1               1607                 7.382746        2663.0
# TTTGTCATCTAGAGTC-1               2192                 7.693026        4351.0
# TTTGTCATCTTACCGC-1               1717                 7.448916        3249.0
#
#                     log1p_total_counts  pct_counts_in_top_50_genes  \
# AAACCTGAGATGCCAG-1            8.325306                   19.946680
# AAACCTGAGGCGCTCT-1            8.532673                   23.616309
# AAACCTGCAACACCTA-1            8.201660                   25.150850
# AAACCTGCATGCCTAA-1            9.211740                   17.367422
# AAACCTGGTCGAACAG-1            7.467942                   26.457143
# ...                                ...                         ...
# TTTGTCATCACATACG-1            7.687080                   22.625057
# TTTGTCATCCCTTGCA-1            7.553287                   27.282267
# TTTGTCATCCGTAGTA-1            7.887584                   20.090124
# TTTGTCATCTAGAGTC-1            8.378391                   26.062974
# TTTGTCATCTTACCGC-1            8.086411                   23.084026
#
#                     pct_counts_in_top_100_genes  pct_counts_in_top_200_genes  \
# AAACCTGAGATGCCAG-1                    25.666505                    33.858459
# AAACCTGAGGCGCTCT-1                    32.263148                    43.116013
# AAACCTGCAACACCTA-1                    32.364235                    41.689523
# AAACCTGCATGCCTAA-1                    25.137321                    35.513832
# AAACCTGGTCGAACAG-1                    34.457143                    45.885714
# ...                                         ...                          ...
# TTTGTCATCACATACG-1                    32.400184                    43.965122
# TTTGTCATCCCTTGCA-1                    35.781742                    46.747114
# TTTGTCATCCGTAGTA-1                    28.051070                    38.715734
# TTTGTCATCTAGAGTC-1                    33.049874                    41.990347
# TTTGTCATCTTACCGC-1                    32.409972                    43.736534
#
#                     pct_counts_in_top_500_genes  total_counts_mt  \
# AAACCTGAGATGCCAG-1                    50.096946            346.0
# AAACCTGAGGCGCTCT-1                    59.661217            320.0
# AAACCTGCAACACCTA-1                    59.544707            214.0
# AAACCTGCATGCCTAA-1                    51.612903            369.0
# AAACCTGGTCGAACAG-1                    64.285714            118.0
# ...                                         ...              ...
# TTTGTCATCACATACG-1                    63.102341             87.0
# TTTGTCATCCCTTGCA-1                    65.372508            157.0
# TTTGTCATCCGTAGTA-1                    58.430342            154.0
# TTTGTCATCTAGAGTC-1                    58.009653            343.0
# TTTGTCATCTTACCGC-1                    62.542321            188.0
#
#                     log1p_total_counts_mt  ...  pct_counts_ribo  \
# AAACCTGAGATGCCAG-1               5.849325  ...         6.180320
# AAACCTGAGGCGCTCT-1               5.771441  ...        12.999803
# AAACCTGCAACACCTA-1               5.370638  ...         8.036204
# AAACCTGCATGCCTAA-1               5.913503  ...         9.557575
# AAACCTGGTCGAACAG-1               4.779123  ...         6.000000
# ...                                   ...  ...              ...
# TTTGTCATCACATACG-1               4.477337  ...        12.941716
# TTTGTCATCCCTTGCA-1               5.062595  ...        10.388247
# TTTGTCATCCGTAGTA-1               5.043425  ...         9.538115
# TTTGTCATCTAGAGTC-1               5.840641  ...         5.492990
# TTTGTCATCTTACCGC-1               5.241747  ...        18.159433
#
#                     total_counts_hb  log1p_total_counts_hb  pct_counts_hb  \
# AAACCTGAGATGCCAG-1              0.0               0.000000       0.000000
# AAACCTGAGGCGCTCT-1              1.0               0.693147       0.019697
# AAACCTGCAACACCTA-1              2.0               1.098612       0.054855
# AAACCTGCATGCCTAA-1              0.0               0.000000       0.000000
# AAACCTGGTCGAACAG-1              0.0               0.000000       0.000000
# ...                             ...                    ...            ...
# TTTGTCATCACATACG-1              0.0               0.000000       0.000000
# TTTGTCATCCCTTGCA-1              0.0               0.000000       0.000000
# TTTGTCATCCGTAGTA-1              2.0               1.098612       0.075103
# TTTGTCATCTAGAGTC-1              1.0               0.693147       0.022983
# TTTGTCATCTTACCGC-1              2.0               1.098612       0.061557
#
#                     n_genes  doublet_score  predicted_doublet  replicate  \
# AAACCTGAGATGCCAG-1     2409       0.027108              False       rep1
# AAACCTGAGGCGCTCT-1     2273       0.037975              False       rep1
# AAACCTGCAACACCTA-1     1929       0.037975              False       rep1
# AAACCTGCATGCCTAA-1     3830       0.039080              False       rep1
# AAACCTGGTCGAACAG-1     1125       0.028660              False       rep1
# ...                     ...            ...                ...        ...
# TTTGTCATCACATACG-1     1304       0.015656              False       rep2
# TTTGTCATCCCTTGCA-1     1160       0.023665              False       rep2
# TTTGTCATCCGTAGTA-1     1607       0.015211              False       rep2
# TTTGTCATCTAGAGTC-1     2192       0.013931              False       rep2
# TTTGTCATCTTACCGC-1     1717       0.016110              False       rep2
#
#                     leiden  leiden_res_0.5
# AAACCTGAGATGCCAG-1       0               0
# AAACCTGAGGCGCTCT-1       1               1
# AAACCTGCAACACCTA-1       1               1
# AAACCTGCATGCCTAA-1       2               2
# AAACCTGGTCGAACAG-1       1               1
# ...                    ...             ...
# TTTGTCATCACATACG-1      18              13
# TTTGTCATCCCTTGCA-1      24              18
# TTTGTCATCCGTAGTA-1      20              15
# TTTGTCATCTAGAGTC-1       1               1
# TTTGTCATCTTACCGC-1      20              15
#
# [17883 rows x 23 columns]

# %% [markdown]
# # Determine differentially expressed marker genes for each cluster

# %%
for res in [0.5,1,2.0]:
    sc.tl.leiden(adata, key_added=f"leiden_res_{res:4.2f}", resolution=res, flavor="igraph")

# %%
sc.pl.umap(
    adata,
    color=["leiden_res_0.5", "leiden_res_1.00", "leiden_res_2.00"],
    legend_loc="on data",
)

# %% [markdown]
# # Inspect some clustering results

# %%
sc.tl.rank_genes_groups(adata, groupby="leiden_res_0.5", method="wilcoxon")
# Out:
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:460: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:463: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:473: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:484: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:460: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:463: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:473: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:484: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:460: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:463: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:473: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:484: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:460: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:463: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:473: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /projectnb/bf528/students/agover11/.conda/envs/scanpy_scrnaseq/lib/python3.13/site-packages/scanpy/tools/_rank_genes_groups.py:484: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(

# %%
sc.get.rank_genes_groups_df(adata, group="0").head(20)
# Out:
#             names     scores  logfoldchanges          pvals      pvals_adj
# 0         Dynlrb2  24.172142        7.555672  4.369153e-129  9.977835e-125
# 1           Plac9  23.876684        4.721154  5.350915e-126  6.109943e-122
# 2         Cfap141  23.129622        7.366498  2.331637e-118  1.774920e-114
# 3         Tmem107  23.029943        5.235972  2.336994e-117  1.334248e-113
# 4             Mia  22.867939        4.739460  9.690268e-116  4.425933e-112
# 5           Elof1  22.772635        3.718635  8.564225e-115  3.259687e-111
# 6          Riiad1  22.478798        5.394022  6.692686e-112  2.183441e-108
# 7           Tppp3  22.311146        5.832541  2.880209e-110  8.221916e-107
# 8         Cfap299  22.071293        7.822657  5.966164e-108  1.513881e-104
# 9             Mt1  21.912436        3.787922  1.977248e-106  4.515441e-103
# 10  1110017D15Rik  21.902637        6.192302  2.451665e-106  5.089880e-103
# 11        Chchd10  21.796087        3.832503  2.527149e-105  4.809375e-102
# 12         Tm4sf1  21.641657        6.019225  7.283921e-104  1.279561e-100
# 13         Tubb4b  21.593843        3.689400  2.052122e-103  3.347452e-100
# 14        Rarres2  21.529736        5.806878  8.199964e-103   1.248417e-99
# 15            Mt2  21.516342        3.776452  1.094662e-102   1.562425e-99
# 16          Foxj1  21.254276        6.979253  3.009645e-100   4.043015e-97
# 17          Meig1  21.116697        6.941692   5.586655e-99   7.087913e-96
# 18          Rsph1  20.959793        7.112600   1.527527e-97   1.836007e-94
# 19         Cfap54  20.695166        5.605712   3.829048e-95   4.372199e-92

# %% [markdown]
# # Applying automatic annotations

# %%
adata_celltypist.layers["counts"]=adata_celltypist.X.copy()
sc.pp.normalize_total(adata_celltypist,target_sum=10000)
sc.pp.log1p(adata_celltypist)
adata_celltypist.obs_names_make_unique()
adata_celltypist.var_names_make_unique()
predictions =

# %%
models.models_description()
# Out:
# 👉 Detailed model information can be found at `https://www.celltypist.org/models`
#                                       model  \
# 0                        Immune_All_Low.pkl
# 1                       Immune_All_High.pkl
# 2                    Adult_COVID19_PBMC.pkl
# 3   Adult_CynomolgusMacaque_Hippocampus.pkl
# 4                       Adult_Human_MTG.pkl
# 5           Adult_Human_PancreaticIslet.pkl
# 6          Adult_Human_PrefrontalCortex.pkl
# 7                      Adult_Human_Skin.pkl
# 8                  Adult_Human_Vascular.pkl
# 9                       Adult_Mouse_Gut.pkl
# 10            Adult_Mouse_OlfactoryBulb.pkl
# 11                Adult_Pig_Hippocampus.pkl
# 12      Adult_RhesusMacaque_Hippocampus.pkl
# 13                Adult_cHSPCs_Illumina.pkl
# 14                  Adult_cHSPCs_Ultima.pkl
# 15                 Autopsy_COVID19_Lung.pkl
# 16         COVID19_HumanChallenge_Blood.pkl
# 17             COVID19_Immune_Landscape.pkl
# 18                   Cells_Adult_Breast.pkl
# 19                     Cells_Fetal_Lung.pkl
# 20                   Cells_Human_Tonsil.pkl
# 21               Cells_Intestinal_Tract.pkl
# 22                    Cells_Lung_Airway.pkl
# 23               Developing_Human_Brain.pkl
# 24              Developing_Human_Gonads.pkl
# 25         Developing_Human_Hippocampus.pkl
# 26              Developing_Human_Organs.pkl
# 27              Developing_Human_Thymus.pkl
# 28               Developing_Mouse_Brain.pkl
# 29         Developing_Mouse_Hippocampus.pkl
# 30            Fetal_Human_AdrenalGlands.pkl
# 31                 Fetal_Human_Pancreas.pkl
# 32                Fetal_Human_Pituitary.pkl
# 33                   Fetal_Human_Retina.pkl
# 34                     Fetal_Human_Skin.pkl
# 35                  Healthy_Adult_Heart.pkl
# 36                 Healthy_COVID19_PBMC.pkl
# 37                  Healthy_Human_Liver.pkl
# 38                  Healthy_Mouse_Liver.pkl
# 39          Human_AdultAged_Hippocampus.pkl
# 40              Human_Colorectal_Cancer.pkl
# 41           Human_Developmental_Retina.pkl
# 42              Human_Embryonic_YolkSac.pkl
# 43              Human_Endometrium_Atlas.pkl
# 44                       Human_IPF_Lung.pkl
# 45       Human_Longitudinal_Hippocampus.pkl
# 46                     Human_Lung_Atlas.pkl
# 47                        Human_PF_Lung.pkl
# 48               Human_Placenta_Decidua.pkl
# 49                  Lethal_COVID19_Lung.pkl
# 50             Mouse_Dendritic_Subtypes.pkl
# 51                  Mouse_Dentate_Gyrus.pkl
# 52          Mouse_Isocortex_Hippocampus.pkl
# 53         Mouse_Postnatal_DentateGyrus.pkl
# 54                    Mouse_Whole_Brain.pkl
# 55                   Nuclei_Lung_Airway.pkl
# 56       PaediatricAdult_COVID19_Airway.pkl
# 57         PaediatricAdult_COVID19_PBMC.pkl
# 58                      Pan_Fetal_Human.pkl
#
#                                           description
# 0   immune sub-populations combined from 20 tissue...
# 1   immune populations combined from 20 tissues of...
# 2   peripheral blood mononuclear cell types from C...
# 3   cell types from the hippocampus of adult cynom...
# 4   cell types and subtypes (10x-based) from the a...
# 5   cell types from pancreatic islets of healthy a...
# 6   cell types and subtypes from the adult human d...
# 7            cell types from human healthy adult skin
# 8   vascular populations combined from multiple ad...
# 9   cell types in the adult mouse gut combined fro...
# 10   cell types from the olfactory bulb of adult mice
# 11          cell types from the adult pig hippocampus
# 12  cell types from the hippocampus of adult rhesu...
# 13  human circulating hematopoietic stem and proge...
# 14  human circulating hematopoietic stem and proge...
# 15  cell types from the lungs of 16 SARS-CoV-2 inf...
# 16  detailed blood cell states from 16 individuals...
# 17  immune subtypes from lung and blood of COVID-1...
# 18             cell types from the adult human breast
# 19    cell types from human embryonic and fetal lungs
# 20      tonsillar cell types from humans (3-65 years)
# 21  intestinal cells from fetal, pediatric (health...
# 22  cell populations from scRNA-seq of five locati...
# 23  cell types from the first-trimester developing...
# 24  cell types of human gonadal and adjacent extra...
# 25   cell types from the developing human hippocampus
# 26  cell types of five endoderm-derived organs in ...
# 27  cell populations in embryonic, fetal, pediatri...
# 28  cell types from the embryonic mouse brain betw...
# 29  cell types from the mouse hippocampus at postn...
# 30  cell types of human fetal adrenal glands from ...
# 31  pancreatic cell types from human embryos at 9-...
# 32  cell types of human fetal pituitaries from 7 t...
# 33  cell types from human fetal neural retina and ...
# 34        cell types from developing human fetal skin
# 35  cell types from eight anatomical regions of th...
# 36  peripheral blood mononuclear cell types from h...
# 37  cell types from scRNA-seq and snRNA-seq of the...
# 38  cell types from scRNA-seq and snRNA-seq of the...
# 39  cell types from the hippocampus of adult and a...
# 40  cell types of colon tissues from patients with...
# 41                 cell types from human fetal retina
# 42  cell types of the human yolk sac from 4-8 post...
# 43  endometrial cell types integrated from seven d...
# 44  cell types from idiopathic pulmonary fibrosis,...
# 45  cell types from the adult human anterior and p...
# 46  integrated Human Lung Cell Atlas (HLCA) combin...
# 47  cell types from different forms of pulmonary f...
# 48  cell types from first-trimester human placenta...
# 49  cell types from the lungs of individuals who d...
# 50  dendritic cell subtypes integrated from 9 data...
# 51  cell types from the dentate gyrus in perinatal...
# 52  cell types from the adult mouse isocortex (neo...
# 53  cell types from the mouse dentate gyrus in pos...
# 54        cell types from the whole adult mouse brain
# 55  cell populations from snRNA-seq of five locati...
# 56  cell types in the airway of paediatric and adu...
# 57  peripheral blood mononuclear cell types of pae...
# 58  stromal and immune populations from the human ...

# %%
adata.obs = adata.obs.join(predictions.predicted_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 adata.obs = adata.obs.join(predictions.predicted_labels)
#
# NameError: name 'predictions' is not defined
